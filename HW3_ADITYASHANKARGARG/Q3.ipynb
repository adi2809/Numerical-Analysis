# %% [markdown]
# # Q3 :
#
# Implement a zero-mean Gaussian process regression model with kernel function as a squared exponential kernel(refer Q.2(a)). Obtain the parameters of kernel function by maximizing the log likelihood. Using trained GP, predict values at $X =1:0.1:4.5$ i.e. $X_0 =1$, $X_n =4.5$ and $dX =0.1$. Plot the predicted mean and the $95$% confidence interval and compare against the actual values.
#
# Note: Actual values are to be calculated using: $Y = 2X^{0.2} − \sin(X)$
# Use the formula above only for cross-checking the final predictions and not in the GP itself.

# %%
from Q3_UTIL import *

# %%
main()
